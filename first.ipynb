# %%
print("hello world!")
# Out:
# hello world!

# %%
a = 1
b = 2

c = a + b
print("this is: ")
print(c)
# Out:
# this is:
# 3

# %%
name = "ali"
lname = "jafari"

print(name)
print(lname)
# Out:
# ali
# jafari

# %%
print(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/hamed/Documents/pyjobs/ec4021/first.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/hamed/Documents/pyjobs/ec4021/first.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> print(z)
#
# NameError: name 'z' is not defined

# %%
print(a)
# Out:
# Running cells with '/Users/hamed/.pyenv/versions/3.12.0/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/hamed/.pyenv/versions/3.12.0/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
a = 20

print(a)
# Out:
# Running cells with '/Users/hamed/.pyenv/versions/3.12.0/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/hamed/.pyenv/versions/3.12.0/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
a = "kamal"

print(a)
# Out:
# Running cells with '/Users/hamed/.pyenv/versions/3.12.0/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/hamed/.pyenv/versions/3.12.0/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
if 5 > 2:
  print("Five is greater than two!")
# Out:
# Running cells with '/Users/hamed/.pyenv/versions/3.12.0/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/hamed/.pyenv/versions/3.12.0/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
if (2+4)>8:
    print("good!")
# Out:
# Running cells with '/Users/hamed/.pyenv/versions/3.12.0/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/hamed/.pyenv/versions/3.12.0/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
no1 = "10"
no2 = "20"

print(no1 + no2)
# Out:
# Running cells with '/Users/hamed/.pyenv/versions/3.12.0/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/hamed/.pyenv/versions/3.12.0/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
name = "ali"
age = "20"

# print(name + age)
# print(name,age)
# print("+")
print(name,"+",age)
# Out:
# Running cells with '/Users/hamed/.pyenv/versions/3.12.0/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/hamed/.pyenv/versions/3.12.0/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
age
# Out:
# Running cells with '/Users/hamed/.pyenv/versions/3.12.0/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/hamed/.pyenv/versions/3.12.0/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
type(name)
# Out:
# Running cells with '/Users/hamed/.pyenv/versions/3.12.0/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/hamed/.pyenv/versions/3.12.0/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
score = int(15)
print(score)
type(score)
# Out:
# Running cells with '/Users/hamed/.pyenv/versions/3.12.0/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/hamed/.pyenv/versions/3.12.0/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# Out:
# Running cells with '/Users/hamed/.pyenv/versions/3.12.0/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/hamed/.pyenv/versions/3.12.0/bin/python -m pip install ipykernel -U --force-reinstall'
