# %%
name = "ali"
print(name)

name = "hasan"
print(name)
# Out:
# ali
# hasan

# %%
# define lists

names = ["ali", "javad", "hasan","maryam","babak"]
print(names)
# Out:
# ['ali', 'javad', 'hasan', 'maryam', 'babak']

# %%
names[0]
# Out:
# 'ali'

# %%
names[3]
# Out:
# 'maryam'

# %%
names[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/hamed/Documents/pyjobs/ec4021/second.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/hamed/Documents/pyjobs/ec4021/second.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> names[4]
#
# IndexError: list index out of range

# %%
len(names)
# Out:
# 4

# %%
names
# Out:
# ['ali', 'hasan', 'javad', 'maryam']

# %%
type(names)
# Out:
# list

# %%
type(name)
# Out:
# str

# %%
print(names)

names.sort()
print(names)

names.sort(reverse=True)
print(names)
# Out:
# ['ali', 'javad', 'hasan', 'maryam', 'babak']
# ['ali', 'babak', 'hasan', 'javad', 'maryam']
# ['maryam', 'javad', 'hasan', 'babak', 'ali']

# %%
name.capitalize()
# Out:
# 'Hasan'

# %%
print(name)
# Out:
# hasan
# 1

# %%
txt = "this is an apple. and realy an apple"
print(txt)

txt.count("apple")
# Out:
# this is an apple. and realy an apple
# 2

# %%
print(txt)
revised_txt = txt.replace("apple","orange")
print(revised_txt)
# Out:
# this is an apple. and realy an apple
# this is an orange. and realy an orange

# %%
# countinue about lists...

ages = [18,22,16,41]
ages
# Out:
# [18, 22, 16, 41]

# %%
sum(ages)
# Out:
# 97

# %%
# names
for xyz in names:
    print(xyz, len(xyz))
# Out:
# maryam 6
# javad 5
# hasan 5
# babak 5
# ali 3

# %%
print(names)
names[3]
# Out:
# ['maryam', 'javad', 'hasan', 'babak', 'ali']
# 'babak'

# %%
names[3] = "bardia"
print(names)
names[3]
# Out:
# ['maryam', 'javad', 'hasan', 'bardia', 'ali']
# 'bardia'
