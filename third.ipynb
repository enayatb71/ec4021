# %%
mylist = [1,2,3,"ali",4]
mylist
# Out:
# [1, 2, 3, 'ali', 4]

# %%
mylist[3]
# Out:
# 'ali'

# %%
mydict = {"fname":"ali", "lname":"rezaii","age":21}
mydict
# Out:
# {'fname': 'ali', 'lname': 'rezaii', 'age': 21}

# %%
mydict["fname"]
# Out:
# 'ali'

# %%
print(mydict["fname"], mydict["age"])
# Out:
# ali 21

# %%
# loops
students = ["ali","hasan","hossein"]
students.sort(reverse=True)
# print(students)

for student in students:
    print("I am ",student)
# Out:
# I am  hossein
# I am  hasan
# I am  ali

# %%
students.sort(reverse=True)
students
# Out:
# ['hossein', 'hasan', 'ali']

# %%
students = [{"fname":"ali","age":20},{"fname":"maryam","age":21}]
# students

for i in students:
    print(i["fname"]," age is:",i["age"])
# Out:
# ali  age is: 20
# maryam  age is: 21

# %%
# print("salam")

# %%
# start using Pandas

import pandas

# print(students)

pandas.DataFrame(students)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/hamed/Documents/pyjobs/ec4021/third.ipynb Cell 10 line 3
#       <a href='vscode-notebook-cell:/Users/hamed/Documents/pyjobs/ec4021/third.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> # start using Pandas
# ----> <a href='vscode-notebook-cell:/Users/hamed/Documents/pyjobs/ec4021/third.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> import pandas
#       <a href='vscode-notebook-cell:/Users/hamed/Documents/pyjobs/ec4021/third.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> # print(students)
#       <a href='vscode-notebook-cell:/Users/hamed/Documents/pyjobs/ec4021/third.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a> pandas.DataFrame(students)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd

df = pd.DataFrame(students)
display(df)

# %%
print(df)

# %%
pd.read
